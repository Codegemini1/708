# %%
if 1 > 5:
    print(True)
else:
    print(False)
# Out:
# False

# %%
1 > 5
# Out:
# False

# %%
if 10 > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Fail

# %%
marks = float(input('Enter your marks'))

if marks > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 50
# Pass

# %%
marks = float(input('Enter your marks'))

if marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 35
# Pass

# %%
marks = float(input('Enter your marks'))

if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 95
# A

# %%
# COURSE INFO

# %%
course = input('Enter your course name')

if course == 'python':
    print('Yes we have python course')
elif course == 'java':
    print('We have java courese')
else:
    print(f'We dont have {course} course.')
# Out:
# Enter your course name JAVA
# We dont have JAVA course.

# %%
'java' == 'python'
# Out:
# False

# %%
'java' == 'java'
# Out:
# True

# %%
course = input('Enter your course name')

if course == 'python':
    print('Yes we have python course')
elif course == 'java':
    print('We have java courese')
else:
    print(f'We dont have {course} course.')

# %%
'JAVA'.lower()
# Out:
# 'java'

# %%
'Java'.lower()
# Out:
# 'java'

# %%
coupon = input('ENter your coupon code')
total = float(input('ENter your totall bill'))

if coupon == 'DATA50':
    discount = total * 0.5
    print(f'You will get discount of {discount}')
    final_price = print(f'Your final total bill is {total - discount}')
elif coupon == 'DATA70':
    discount = total * 0.7
    print(f'You will get discount of {discount}')
    final_price = print(f'Your final total bill is {total - discount}')
else:
    print('Coupon code is not valid')
    print(f'Your final price will be {total} $')
# Out:
# ENter your coupon code DATA50
# ENter your totall bill 1000
# You will get discount of 500.0
# Your final total bill is 500.0

# %%
100 * 0.7
# Out:
# 70.0

# %%
100 * 0.5
# Out:
# 50.0

# %%
# Similar code for course, discount

# %%
marks = float(input('Enter your marks'))

if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 120
# A

# %%
marks = float(input('Enter your marks'))

if marks >= 90 and marks <= 100: # True and False --->f
    print('A')
elif marks >= 70 and marks < 90: # True and False
    print('B')
elif marks >= 50 and marks < 70: # T and F
    print('C')
elif marks >= 35 and marks < 50: # T and F
    print('Pass')
elif marks >= 0 and marks < 35: # T and F
    print('Fail')
else:
    print('Please write marks between 0-100 range')
# Out:
# Enter your marks 5
# Fail

# %%
120 > 90

# %%
120 >= 90 and 120 <= 100 # True and False

# %%
120 >= 90
# Out:
# True

# %%
120 <= 100
# Out:
# False

# %%
# even odd

# %%
10 % 2 # --> Even
# Out:
# 0

# %%
9 % 2  # --> Odd
# Out:
# 1

# %%
num = int(input('Enter your num'))
if num % 2 == 0:
    print('Even num', num)
elif num % 2 != 0:
    print('Odd', num)
else:
    print('Please rewrite num')
# Out:
# Enter your num 5
# Odd 5
