# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %% [markdown]
# # First Day

# %% [markdown]
# Today we are going to start python

# %% [markdown]
# # Heading

# %% [markdown]
# hdgvshjdg

# %% [raw]
# x ---> 867
# y ---> 765
# d ---> 8236
# jhdv
# sjlskfdj

# %%
print(10 * 5)
# Out:
# 50

# %%
print(10 * 5)
print(10 - 5)
print(10 % 2)
# Out:
# 50
# 5
# 0
