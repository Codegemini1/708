# %%
a = 5

# %%
a
# Out:
# 5

# %%
b = 1

# %%
b
# Out:
# 1

# %%
a + b
# Out:
# 6

# %%
type(b)
# Out:
# int

# %%
a * b
# Out:
# 5

# %%
c = a + b

# %%
c
# Out:
# 6

# %%
x,y,z = 10,20,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
o = 1,2,3,4,5

# %%
o
# Out:
# (1, 2, 3, 4, 5)

# %%
5 = 120
# Out:
#   Cell In[16], line 1
#     5 = 120
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a5 = 120

# %%
a_5 = 120

# %%
a5
# Out:
# 120

# %%
a_5
# Out:
# 120

# %%
a 5 = 120
# Out:
#   Cell In[21], line 1
#     a 5 = 120
#       ^
# SyntaxError: invalid syntax

# %%
name = 'Vaibhav'

# %%
name
# Out:
# 'Vaibhav'

# %%
last_name = 'Bhosale'

# %%
last_name
# Out:
# 'Bhosale'

# %%
name + last_name
# Out:
# 'VaibhavBhosale'

# %%
@y = 5
# Out:
#   Cell In[27], line 1
#     @y = 5
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
type(name)
# Out:
# str

# %%
type = 'Hello'

# %%
type
# Out:
# 'Hello'

# %%
type(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 type(1)
#
# TypeError: 'str' object is not callable

# %%
# Operations

# %%
name
# Out:
# 'Vaibhav'

# %%
last_name
# Out:
# 'Bhosale'

# %%
name + ' ' + last_name
# Out:
# 'Vaibhav Bhosale'

# %%
'5'
# Out:
# '5'

# %%
num = '5'

# %%
num
# Out:
# '5'

# %%
type(num)
# Out:
# str

# %%
# str ---> int

# %%
int(num)
# Out:
# 5

# %%
int('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int('Hello')
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
int(15.32324)
# Out:
# 15

# %%
float(5)
# Out:
# 5.0

# %%
# typecasting --> changing one data type to another one

# %%
str(123)
# Out:
# '123'
