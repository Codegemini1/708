# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
5 > 1
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %%
5 >= 10
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 > 1 & 10 < 20  # True & True
# Out:
# True

# %%
'hello' == 'hello'
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
a = 5

# %%
5 == 5
# Out:
# True

# %%
a == 5
# Out:
# True

# %%
'exit' == 'exit'
# Out:
# True

# %%
'Hi' != 'By'
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
'Hello' != 'hello'
# Out:
# True

# %%
'exit' != 'exit'
# Out:
# False

# %%
'hi'
# Out:
# 'hi'

# %%
age = 50

# %%
print('My age is', age)
# Out:
# My age is 50

# %%
print(f'My age is {age}  and i am very good person')
# Out:
# My age is 50  and i am very good person

# %%
name = 'xyz'

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is xyz and my age is 50

# %%
name = input('Write your good name')
print(f'My name is {name}')
# Out:
# Wrtite your good name Om
# My name is Om

# %%
type(name)
# Out:
# str

# %%
age = input('Enter your age')
print(f'Your age is {age}')
# Out:
# Enter your age 65
# Your age is 65

# %%
type(age)
# Out:
# str

# %%
age = int(input('ENter your age'))
print(f'Your age is {age}')
# Out:
# ENter your age 55
# Your age is 55

# %%
type(age)
# Out:
# int

# %%
# input --> str

# %%
student_name = input('Enter student name')
marks = float(input('Enter your marks'))
print(f'Student name is {student_name} and marks are {marks} ')
# Out:
# Enter student name Sham
# Enter your marks 78
# Student name is Sham and marks are 78.0

# %% [markdown]
# # Data strectures

# %%
# list

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
mix = [1,15.2,10+5j,True, 'Hello']

# %%
mix
# Out:
# [1, 15.2, (10+5j), True, 'Hello']

# %%
type(mix)
# Out:
# list

# %%
names = ['Om', 'Sham', 'Sham', 'Ramesh']

# %%
names
# Out:
# ['Om', 'Sham', 'Sham', 'Ramesh']
